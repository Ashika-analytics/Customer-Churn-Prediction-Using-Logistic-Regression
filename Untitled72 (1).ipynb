# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/customer_churn_dataset-testing-master.csv")

# %%
df
# Out:
#        CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0               1   22  Female      25               14              4
# 1               2   41  Female      28               28              7
# 2               3   47    Male      27               10              2
# 3               4   35    Male       9               12              5
# 4               5   53  Female      58               24              9
# ...           ...  ...     ...     ...              ...            ...
# 64369       64370   45  Female      33               12              6
# 64370       64371   37    Male       6                1              5
# 64371       64372   25    Male      39               14              8
# 64372       64373   50  Female      18               19              7
# 64373       64374   52  Female      45               15              9
#
#        Payment Delay Subscription Type Contract Length  Total Spend  \
# 0                 27             Basic         Monthly          598
# 1                 13          Standard         Monthly          584
# 2                 29           Premium          Annual          757
# 3                 17           Premium       Quarterly          232
# 4                  2          Standard          Annual          533
# ...              ...               ...             ...          ...
# 64369             21             Basic       Quarterly          947
# 64370             22          Standard          Annual          923
# 64371             30           Premium         Monthly          327
# 64372             22          Standard         Monthly          540
# 64373             25          Standard         Monthly          696
#
#        Last Interaction  Churn
# 0                     9      1
# 1                    20      0
# 2                    21      0
# 3                    18      0
# 4                    18      0
# ...                 ...    ...
# 64369                14      1
# 64370                 9      1
# 64371                20      1
# 64372                13      1
# 64373                22      1
#
# [64374 rows x 12 columns]

# %%
df.shape
# Out:
# (64374, 12)

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'Usage Frequency',
#        'Support Calls', 'Payment Delay', 'Subscription Type',
#        'Contract Length', 'Total Spend', 'Last Interaction', 'Churn'],
#       dtype='object')

# %%
df.dtypes
# Out:
# CustomerID            int64
# Age                   int64
# Gender               object
# Tenure                int64
# Usage Frequency       int64
# Support Calls         int64
# Payment Delay         int64
# Subscription Type    object
# Contract Length      object
# Total Spend           int64
# Last Interaction      int64
# Churn                 int64
# dtype: object

# %%
df['Contract Length'].unique()
# Out:
# array(['Monthly', 'Annual', 'Quarterly'], dtype=object)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
plt.figure()
sns.histplot(df['Tenure'],bins=30)
plt.title("Distribution of Customer Tenure")
plt.xlabel("Tenure (Months)")
plt.ylabel("Count")
plt.show()

# %%
plt.figure()
sns.boxplot(x='Churn', y='Tenure', data=df)
plt.title("Tenure vs Churn")
plt.xlabel("Churn")
plt.ylabel("Tenure (Months)")
plt.show()

# %% [markdown]
# 1--->churn,0----->no churn

# %%
df['Churn'].value_counts()
# Out:
# Churn
# 0    33881
# 1    30493
# Name: count, dtype: int64

# %%
plt.figure()
sns.histplot(df['Total Spend'],bins=30)
plt.title("Distribution of Total spend")
plt.xlabel("Total spend")
plt.ylabel("Count")
plt.show()

# %%
plt.figure()
sns.boxplot(x='Churn',y='Total Spend',data=df)
plt.title("Churn vs Total spend")
plt.xlabel("Churn")
plt.ylabel("Total spend")
plt.show()

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'Usage Frequency',
#        'Support Calls', 'Payment Delay', 'Subscription Type',
#        'Contract Length', 'Total Spend', 'Last Interaction', 'Churn'],
#       dtype='object')

# %%
contract_churn = df.groupby('Contract Length')['Churn'].mean()
print(contract_churn)
# Out:
# Contract Length
# Annual       0.462167
# Monthly      0.516087
# Quarterly    0.440482
# Name: Churn, dtype: float64

# %%
contract_churn.plot(kind='bar')
plt.title("Churn Rate by Contract Length")
plt.ylabel("Churn Rate")
plt.show()

# %%
subscription_churn = df.groupby('Subscription Type')['Churn'].mean()

print(subscription_churn)
# Out:
# Subscription Type
# Basic       0.482775
# Premium     0.464964
# Standard    0.473305
# Name: Churn, dtype: float64

# %%
subscription_churn.plot(kind='bar')
plt.title("Churn Rate by Subscription Type")
plt.ylabel("Churn Rate")
plt.show()

# %%
df.groupby(['Contract Length', 'Subscription Type'])['Churn'].mean()
# Out:
# Contract Length  Subscription Type
# Annual           Basic                0.471321
#                  Premium              0.456396
#                  Standard             0.458745
# Monthly          Basic                0.521090
#                  Premium              0.508706
#                  Standard             0.518508
# Quarterly        Basic                0.453824
#                  Premium              0.426986
#                  Standard             0.440649
# Name: Churn, dtype: float64

# %%
df.head(2)
# Out:
#    CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0           1   22  Female      25               14              4
# 1           2   41  Female      28               28              7
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0             27             Basic         Monthly          598
# 1             13          Standard         Monthly          584
#
#    Last Interaction  Churn
# 0                 9      1
# 1                20      0

# %%
df.corr(numeric_only=True)
# Out:
#                   CustomerID       Age    Tenure  Usage Frequency  \
# CustomerID          1.000000  0.043287  0.103296        -0.062699
# Age                 0.043287  1.000000 -0.007763        -0.038331
# Tenure              0.103296 -0.007763  1.000000         0.023485
# Usage Frequency    -0.062699 -0.038331  0.023485         1.000000
# Support Calls       0.164175  0.005014  0.060065        -0.014072
# Payment Delay       0.290684 -0.016132  0.055963         0.031132
# Total Spend        -0.037068  0.006490  0.009474         0.001527
# Last Interaction   -0.003718 -0.000148  0.005770        -0.009192
# Churn               0.529832  0.063457  0.195327        -0.115098
#
#                   Support Calls  Payment Delay  Total Spend  Last Interaction  \
# CustomerID             0.164175       0.290684    -0.037068         -0.003718
# Age                    0.005014      -0.016132     0.006490         -0.000148
# Tenure                 0.060065       0.055963     0.009474          0.005770
# Usage Frequency       -0.014072       0.031132     0.001527         -0.009192
# Support Calls          1.000000       0.064298     0.021750          0.001666
# Payment Delay          0.064298       1.000000    -0.031119         -0.008076
# Total Spend            0.021750      -0.031119     1.000000         -0.007692
# Last Interaction       0.001666      -0.008076    -0.007692          1.000000
# Churn                  0.304631       0.557386    -0.078867         -0.002818
#
#                      Churn
# CustomerID        0.529832
# Age               0.063457
# Tenure            0.195327
# Usage Frequency  -0.115098
# Support Calls     0.304631
# Payment Delay     0.557386
# Total Spend      -0.078867
# Last Interaction -0.002818
# Churn             1.000000

# %%
df.corr(numeric_only=True)['Churn'].sort_values()
# Out:
# Usage Frequency    -0.115098
# Total Spend        -0.078867
# Last Interaction   -0.002818
# Age                 0.063457
# Tenure              0.195327
# Support Calls       0.304631
# CustomerID          0.529832
# Payment Delay       0.557386
# Churn               1.000000
# Name: Churn, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), cmap='coolwarm', annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'Usage Frequency',
#        'Support Calls', 'Payment Delay', 'Subscription Type',
#        'Contract Length', 'Total Spend', 'Last Interaction', 'Churn'],
#       dtype='object')

# %%
sns.boxplot(data=df,x='Churn',y='Support Calls')
# Out:
# <Axes: xlabel='Churn', ylabel='Support Calls'>

# %%
sns.scatterplot(x='Tenure', y='Total Spend', hue='Churn', data=df)
# Out:
# <Axes: xlabel='Tenure', ylabel='Total Spend'>

# %%
df.groupby('Gender')['Churn'].mean()
# Out:
# Gender
# Female    0.550490
# Male      0.385797
# Name: Churn, dtype: float64

# %%
df.groupby('Gender')['Churn'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
df['Churn'].unique()
# Out:
# array([1, 0])

# %%
X = df.drop('Churn', axis=1)
y = df['Churn']

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
sns.scatterplot(x='Tenure', y='Total Spend', hue='Churn', data=df)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.metrics import classification_report
y_pred = log_reg.predict(X_test_scaled)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87      6776
#            1       0.85      0.85      0.85      6099
#
#     accuracy                           0.86     12875
#    macro avg       0.86      0.86      0.86     12875
# weighted avg       0.86      0.86      0.86     12875

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[5891,  885],
#        [ 906, 5193]])

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')

plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix – Logistic Regression (Churn Prediction)')

plt.show()
